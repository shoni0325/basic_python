# %% [markdown]
# # selenium 라이브러리
# 1. 웹 어플리케이션 테스트를 위한 라이브러리
# 2. python에서 웹브라우져를 제어하는 기능
# 3. 웹드라이버를 별도 설치 필요

# %%
# 라이브러리 설치
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (4.8.3)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from selenium) (1.26.15)
# Requirement already satisfied: trio~=0.17 in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from selenium) (0.10.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (22.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from trio-websocket~=0.9->selenium) (1.1.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\shoni\appdata\local\programs\python\python311\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
# 라이브러리 로드
from selenium import webdriver

# %%
# 웹드라이버 파일의 위치 지정
path = "../chromedriver.exe"

# %%
# 웹드라이버 실행
driver = webdriver.Chrome(path)
# Out:
# C:\Users\shoni\AppData\Local\Temp\ipykernel_18156\1474807558.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %%
# 웹 주소창에 값을 입력
driver.get('https://www.naver.com')

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
# 검색어창 지정
element = driver.find_element(By.ID, 'query')

# %%
# element에 입력할 값을 지정
element.send_keys("날씨")

# %%
element.send_keys(Keys.ENTER)

# %%
from bs4 import BeautifulSoup as bs

# %%
soup = bs(driver.page_source, 'html.parser')

# %%
data = soup.find('ul', attrs = {
    'class' : 'list_news'
})

data
# Out:
# <ul class="list_news"> <li class="bx" id="sp_nws_all1"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="https://www.yna.co.kr/view/AKR20230410129351081?input=1195m" href="#" onclick="tCR('a=nws_all*h.kep&amp;r=1&amp;i=880000D8_000000000000000013871551&amp;u=javascript'); return false;" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws_all*h.kepoff&amp;r=1&amp;i=880000D8_000000000000000013871551&amp;u=javascript" data-cr-on="a=nws_all*h.kepon&amp;r=1&amp;i=880000D8_000000000000000013871551&amp;u=javascript" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws_all*h.kephome&amp;r=1&amp;i=880000D8_000000000000000013871551&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div></div><div class="info_group"> <a class="info press" href="https://www.yna.co.kr/" onclick="return goOtherCR(this, 'a=nws_all*h.prof&amp;r=1&amp;i=880000D8_000000000000000013871551&amp;g=001.0013871551&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F001%2F2017%2F06%2F29%2Flogo_001_18_20170629160329.png&amp;type=f54_54&amp;expire=24&amp;refresh=true" data-obstatus="ob-once" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="20"/></span>연합뉴스<i class="spnew ico_pick">언론사 선정</i></a><span class="info">12시간 전</span><a class="info" href="https://n.news.naver.com/mnews/article/001/0013871551?sid=104" onclick="return goOtherCR(this, 'a=nws_all*h.nav&amp;r=1&amp;i=880000D8_000000000000000013871551&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </div></div><a class="news_tit" href="https://www.yna.co.kr/view/AKR20230410129351081?input=1195m" onclick="return goOtherCR(this, 'a=nws_all*h.tit&amp;r=1&amp;i=880000D8_000000000000000013871551&amp;g=001.0013871551&amp;u='+urlencode(this.href));" target="_blank" title='프랑스 몽블랑 눈사태로 6명 사망…"따뜻해진 날씨 영향일 수도"(종합)'>프랑스 몽블랑 눈사태로 6명 사망…"따뜻해진 <mark>날씨</mark> 영향일 수도"(종합)</a> <div class="news_dsc"> <div class="dsc_wrap"> <a class="api_txt_lines dsc_txt_wrap" href="https://www.yna.co.kr/view/AKR20230410129351081?input=1195m" onclick="return goOtherCR(this, 'a=nws_all*h.body&amp;r=1&amp;i=880000D8_000000000000000013871551&amp;g=001.0013871551&amp;u='+urlencode(this.href));" target="_blank">기상청은 당일 눈사태 경보를 발령하지 않았지만 오트사부아 당국은 따뜻한 <mark>날씨</mark>와 바람이 복합적으로 눈사태를 일으켰을 수 있다고 추정했다. 이 지역에서는 지난 2014년 12월 25일 눈사태가 발생해 산악 경험이 많은...</a> </div></div></div><a class="dsc_thumb" href="https://www.yna.co.kr/view/AKR20230410129351081?input=1195m" onclick="return goOtherCR(this, 'a=nws_all*h.img&amp;r=1&amp;i=880000D8_000000000000000013871551&amp;g=001.0013871551&amp;u='+urlencode(this.href));" target="_blank"><img alt="프랑스 몽블랑 눈사태" class="thumb api_get" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F001%2F2023%2F04%2F11%2F13871551.jpg&amp;type=ff264_180&amp;expire=2&amp;refresh=true" data-obstatus="ob-once" height="90" onerror="this.parentNode.style.display='none';" src="..." width="132"/></a> </div><div class="news_cluster"> <ul class="list_cluster"> <li class="sub_bx"> <span class="sub_wrap"> <span class="sub_area"> <cite class="sub_txt press" title="한국경제TV">한국경제TV</cite><span class="sub_txt">8시간 전</span><a class="sub_txt" href="https://n.news.naver.com/mnews/article/215/0001094516?sid=104" onclick="return goOtherCR(this, 'a=nws_all*c.nav&amp;r=2&amp;i=88000149_000000000000000001094516&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </span><a class="elss sub_tit" href="http://www.wowtv.co.kr/NewsCenter/News/Read?ar ...

# %%
_list = data.find_all('a', attrs = {
    'class' : 'news_tit'
})

# %%
result = []
for i in _list :
    result.append(i.get_text())
result
# Out:
# ['프랑스 몽블랑 눈사태로 6명 사망…"따뜻해진 날씨 영향일 수도"(종합)',
#  "오늘의 날씨, 비온 뒤 기온 뚝…미세먼지 '나쁨'",
#  "[오늘의 날씨] 황사 덮쳐 미세먼지 '나쁨'…전국 잠시 '흙비'",
#  "아침부터 '황사비'에 돌풍…수도권 미세먼지 '매우나쁨'[내일날씨]"]

# %%
# 네이버증권 - 현대차 정보 가져오기

# %%
driver = webdriver.Chrome(path)
code = '005380'
driver.get("https://navercomp.wisereport.co.kr/v2/company/c1010001.aspx?cmp_cd=" + code)
# Out:
# C:\Users\shoni\AppData\Local\Temp\ipykernel_18156\615708931.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %%
# 이번엔 enter가 아니라 클릭
element = driver.find_element(By.CLASS_NAME, 'menu')
print(element)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="7d03a4e1a8a26455dc73579972ab5f42", element="190707e6-415a-4b7e-8b95-8ba99b34794e")>

# %%
element2 = element.find_elements(By.TAG_NAME, 'a')[3]
element2.click()
# print(element2)

# %%
soup = bs(driver.page_source, 'html.parser')

# %%
data = soup.find_all('table', attrs={
    'class' : 'gHead01 all-width data-list'
})[1]

# %%
# 컬럼 부분에 들어갈 값을 추출
_list = data.find_all('th')

# %%
col_list = []
for i in _list :
    col_list.append(i.get_text())
col_list
# Out:
# ['항목',
#  '\n2018/12(IFRS연결)\n',
#  '\n2019/12(IFRS연결)\n',
#  '\n2020/12(IFRS연결)\n',
#  '\n2021/12(IFRS연결)\n',
#  '\n2022/12(IFRS연결)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t연간컨센서스보기\n\n',
#  '\n2023/12(E)(IFRS연결)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t연간컨센서스닫기\n\n',
#  '\n전년대비(YoY)\n',
#  '\n전년대비(YoY)\n']

# %%
# value값을 추출
data2 = data.find('tbody')

# %%
data3 = data2.find_all('tr')

# %%
data3[0].find_all('td')
# Out:
# [<td class="txt" title="EPS">
#  <span class="cut">
#  <a class="btn_moreE" data-acc="312000"><span class="icon-sprite icon-moreE">펼치기</span></a>
#
#  												EPS
#  													</span>
#  </td>,
#  <td class="num ext0">5,352</td>,
#  <td class="num ext1">10,761</td>,
#  <td class="num ext2">5,143</td>,
#  <td class="num ext3">17,846</td>,
#  <td class="num ext4">26,592</td>,
#  <td class="num ext5">31,707</td>,
#  <td class="num ext6 noline-right">49</td>,
#  <td class="num ext7 noline-right">19</td>]

# %%
value_list = []

# 첫번째 for문은 인덱스를 자르는 for문
for i in data3 :
    sample_list = []
    _list = i.find_all('td')
    for j in _list :
        sample_list.append(j.get_text())
    value_list.append(sample_list)

value_list
# Out:
# [['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tEPS\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '5,352',
#   '10,761',
#   '5,143',
#   '17,846',
#   '26,592',
#   '31,707',
#   '49',
#   '19'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t당기순이익(지배)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '15,080.8',
#   '29,800.5',
#   '14,244.4',
#   '49,423.6',
#   '73,643.6',
#   '87,009.1',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정평균발행주식수＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '217,415,903',
#   '213,668,187',
#   '213,668,187',
#   '213,668,187',
#   '213,668,187',
#   '211,724,685',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t우선주수정평균발행주식수＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '64,366,142',
#   '63,270,871',
#   '63,270,871',
#   '63,270,871',
#   '63,270,871',
#   '62,695,368',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tBPS\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '256,422',
#   '267,549',
#   '266,968',
#   '289,609',
#   '315,142',
#   '347,220',
#   '9',
#   '10'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t자본총계(지배)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '679,739.7',
#   '700,658.0',
#   '694,806.3',
#   '749,861.2',
#   '823,492.9',
#   '909,438.6',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정기말발행주식수(자사주차감)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '204,280,606',
#   '201,833,036',
#   '200,576,769',
#   '199,619,945',
#   '202,259,476',
#   '202,870,846',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t우선주수정기말발행주식수(자사주차감)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '60,805,434',
#   '60,047,227',
#   '59,681,734',
#   '59,302,110',
#   '59,049,027',
#   '59,049,027',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tCPS\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '13,359',
#   '1,516',
#   '-1,480',
#   '-4,248',
#   '38,374',
#   '52,979',
#   '1,003',
#   '38'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t영업활동현금흐름＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '37,642.7',
#   '4,197.8',
#   '-4,098.1',
#   '-11,764.2',
#   '106,273.1',
#   '136,265.8',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정평균발행주식수＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '217,415,903',
#   '213,668,187',
#   '213,668,187',
#   '213,668,187',
#   '213,668,187',
#   '211,724,685',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t우선주수정평균발행주식수＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '64,366,142',
#   '63,270,871',
#   '63,270,871',
#   '63,270,871',
#   '63,270,871',
#   '62,695,368',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tSPS\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '343,573',
#   '381,840',
#   '375,525',
#   '424,681',
#   '514,653',
#   '547,878',
#   '21',
#   '6'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t매출액＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '968,126.1',
#   '1,057,464.2',
#   '1,039,976.0',
#   '1,176,106.3',
#   '1,425,275.4',
#   '1,503,487.4',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정평균발행주식수＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '217,415,903',
#   '213,668,187',
#   '213,668,187',
#   '213,668,187',
#   '213,668,187',
#   '211,724,685',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t우선주수정평균발행주식수＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '64,366,142',
#   '63,270,871',
#   '63,270,871',
#   '63,270,871',
#   '63,270,871',
#   '62,695,368',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tPER\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '22.14',
#   '11.20',
#   '37.33',
#   '11.71',
#   '5.68',
#   '5.86',
#   '-51.51',
#   '3.25'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정주가(기말)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '118,500',
#   '120,500',
#   '192,000',
#   '209,000',
#   '151,000',
#   '185,900',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tEPS＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '5,352',
#   '10,761',
#   '5,143',
#   '17,846',
#   '26,592',
#   '31,707',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tPBR\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '0.46',
#   '0.45',
#   '0.72',
#   '0.72',
#   '0.48',
#   '0.54',
#   '-33.60',
#   '11.74'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정주가(기말)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '118,500',
#   '120,500',
#   '192,000',
#   '209,000',
#   '151,000',
#   '185,900',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tBPS＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '256,422',
#   '267,549',
#   '266,968',
#   '289,609',
#   '315,142',
#   '347,220',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tPCR\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '8.87',
#   '79.50',
#   '-129.75',
#   '-49.20',
#   '3.93',
#   '3.51',
#   '108.00',
#   '-10.83'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정주가(기말)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '118,500',
#   '120,500',
#   '192,000',
#   '209,000',
#   '151,000',
#   '185,900',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tCPS＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '13,359',
#   '1,516',
#   '-1,480',
#   '-4,248',
#   '38,374',
#   '52,979',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tPSR\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '0.34',
#   '0.32',
#   '0.51',
#   '0.49',
#   '0.29',
#   '0.34',
#   '-40.38',
#   '15.65'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t보통주수정주가(기말)＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '118,500',
#   '120,500',
#   '192,000',
#   '209,000',
#   '151,000',
#   '185,900',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tSPS＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '343,573',
#   '381,840',
#   '375,525',
#   '424,681',
#   '514,653',
#   '547,878',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tEV/EBITDA\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '12.37',
#   '11.75',
#   '16.57',
#   '11.37',
#   '7.96',
#   '7.87',
#   '-30.00',
#   '-1.17'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tEV＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '765,044.6',
#   '873,635.9',
#   '1,090,036.7',
#   '1,277,281.6',
#   '1,183,246.9',
#   '1,246,554.0',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tEBITDA＜당기＞\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '61,836.3',
#   '74,373.8',
#   '65,800.4',
#   '112,346.9',
#   '148,673.9',
#   '158,484.6',
#   '\xa0',
#   '\xa0'],
#  ['\n\n펼치기\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\tDPS\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '4,000',
#   '4,000',
#   '3,000',
#   '5,000',
#   '7,000',
#   '',
#   '40',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t현금DPS\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '4,000',
#   '4,000',
#   '3,000',
#   '5,000',
#   '7,000',
#   '',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t주식DPS\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '0',
#   '0',
#   '0',
#   '0',
#   '',
#   '',
#   '\xa0',
#   '\xa0'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t현금배당수익률\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '3.38',
#   '3.32',
#   '1.56',
#   '2.39',
#   '4.64',
#   '3.71',
#   '2.24',
#   '-0.93'],
#  ['\n\n\xa0\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t현금배당성향(%)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n',
#   '70.70',
#   '35.35',
#   '55.15',
#   '26.32',
#   '24.85',
#   '16.76',
#   '-1.46',
#   '-8.10']]

# %%
col_list
# Out:
# ['항목',
#  '\n2018/12(IFRS연결)\n',
#  '\n2019/12(IFRS연결)\n',
#  '\n2020/12(IFRS연결)\n',
#  '\n2021/12(IFRS연결)\n',
#  '\n2022/12(IFRS연결)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t연간컨센서스보기\n\n',
#  '\n2023/12(E)(IFRS연결)\n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t\t연간컨센서스닫기\n\n',
#  '\n전년대비(YoY)\n',
#  '\n전년대비(YoY)\n']

# %%
col = []
for i in col_list :
    result = i.replace('\n', "")
    result = result.replace("연간컨센서스보기", "").replace("연간컨센서스닫기", "")
    col.append(result.strip())

col
# Out:
# ['항목',
#  '2018/12(IFRS연결)',
#  '2019/12(IFRS연결)',
#  '2020/12(IFRS연결)',
#  '2021/12(IFRS연결)',
#  '2022/12(IFRS연결)',
#  '2023/12(E)(IFRS연결)',
#  '전년대비(YoY)',
#  '전년대비(YoY)']

# %%
import pandas as pd

# %%
df = pd.DataFrame(value_list, columns=col)

# %%
def change(x) :
    result = x.replace("\n", "")
    result = result.replace("\t", "")
    result = result.replace("펼치기", "")
    return result

df['항목'] = df['항목'].apply(change)

# %%
df.columns
# Out:
# Index(['항목', '2018/12(IFRS연결)', '2019/12(IFRS연결)', '2020/12(IFRS연결)',
#        '2021/12(IFRS연결)', '2022/12(IFRS연결)', '2023/12(E)(IFRS연결)', '전년대비(YoY)',
#        '전년대비(YoY)'],
#       dtype='object')

# %%
df.columns = ['항목', '2018/12(IFRS연결)', '2019/12(IFRS연결)', '2020/12(IFRS연결)',
       '2021/12(IFRS연결)', '2022/12(IFRS연결)', '2023/12(E)(IFRS연결)', '전년대비(2022)', '전년대비(2023)']

# %%
from datetime import datetime

# %%
now = datetime.now()
now = now.strftime("%Y%m%d%H%M%S")
now
# Out:
# '20230411135854'

# %%
df

# %%
df.to_csv(f"test{now}.csv", index=False)

# %%
pd.read_csv("test.csv")
# Out:
#     Unnamed: 0                        항목  ... 전년대비(2022) 전년대비(2023)
# 0            0                       EPS  ...         49         19
# 1            1             당기순이익(지배)＜당기＞  ...
# 2            2          보통주수정평균발행주식수＜당기＞  ...
# 3            3          우선주수정평균발행주식수＜당기＞  ...
# 4            4                       BPS  ...          9         10
# 5            5              자본총계(지배)＜당기＞  ...
# 6            6   보통주수정기말발행주식수(자사주차감)＜당기＞  ...
# 7            7   우선주수정기말발행주식수(자사주차감)＜당기＞  ...
# 8            8                       CPS  ...      1,003         38
# 9            9              영업활동현금흐름＜당기＞  ...
# 10          10          보통주수정평균발행주식수＜당기＞  ...
# 11          11          우선주수정평균발행주식수＜당기＞  ...
# 12          12                       SPS  ...         21          6
# 13          13                   매출액＜당기＞  ...
# 14          14          보통주수정평균발행주식수＜당기＞  ...
# 15          15          우선주수정평균발행주식수＜당기＞  ...
# 16          16                       PER  ...     -51.51       3.25
# 17          17           보통주수정주가(기말)＜당기＞  ...
# 18          18                   EPS＜당기＞  ...
# 19          19                       PBR  ...     -33.60      11.74
# 20          20           보통주수정주가(기말)＜당기＞  ...
# 21          21                   BPS＜당기＞  ...
# 22          22                       PCR  ...     108.00     -10.83
# 23          23           보통주수정주가(기말)＜당기＞  ...
# 24          24                   CPS＜당기＞  ...
# 25          25                       PSR  ...     -40.38      15.65
# 26          26           보통주수정주가(기말)＜당기＞  ...
# 27          27                   SPS＜당기＞  ...
# 28          28                 EV/EBITDA  ...     -30.00      -1.17
# 29          29                    EV＜당기＞  ...
# 30          30                EBITDA＜당기＞  ...
# 31          31                       DPS  ...         40
# 32          32                     현금DPS  ...
# 33          33                     주식DPS  ...
# 34          34                   현금배당수익률  ...       2.24      -0.93
# 35          35                 현금배당성향(%)  ...      -1.46      -8.10
#
# [36 rows x 10 columns]
